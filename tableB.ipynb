# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Get Data from Excel Spreadsheets into Dataframes for each year

# %%
df2008 = pd.read_excel("input/rakeToss2008-B.xls", sheet_name="TableB_AbundanceSpecies")
df2008.head()

for col in df2008.columns:
    df2008.rename(columns={col:col.strip().replace(" ","_")},inplace=True)
df2008.columns

scientific_names = {
    "Autumnal_Water_Starwort": "Callitriche_hermaphroditica", 
    "Bassweed": "Potamogeton_amplifolius",
    "Benthic_Filamentous_Algae": "Benthic_Filamentous_Algae",
    "Clasping_Leaf_Pondweed": "Potamogeton_richardsonii",
    "Common_Bladderwort": "Utricularia_vulgaris", 
    "Common_Waterweed": "Elodea_sp.", 
    "Coontail": "Ceratophyllum_demersum",
    "Curlyleaf_Pondweed": "Potamogeton_crispus",
    "Eurasian_Watermilfoil": "Myriophyllum_spicatum",
    "Flatstem_Pondweed": "Potamogeton_zosteriformis ",
    "Floating_Filamentous_Algae": "Floating_Filamentous_Algae",
    "Forked_Duckweed": "Lemna_trisulca",
    "Great_Duckweed": "Spirodela_polyrhiza",
    "Illinois_Pondweed": "Potamogeton_illinoensis",
    "Leafy_Pondweed": "Potamogeton_foliosus",
    "Muskgrass": "Chara_vulgaris",
    "Sago_Pondweed": "Potamogeton_pectinatus",
    "Slender_Naiad": "Najas_flexilis",
    "Small_Duckeed": "Lemna_minor",
    "Spatterdock": "Nuphar_variegata",
    "Tapegrass": "Vallisneria_americana",
    "Variable-Leaf_Pondweed": "Potamogeton_gramineus",
    "White_Stem_Pondweed": "Potamogeton_praelongus",
    "Water_Marigold": "Megalodonta_beckii",
    "Common_Watermeal": "Wolffia_columbiana",
    "Watermoss": "Fontinalis_sp.",
    "Water_Stargrass": "Heteranthera_dubia",
    "White_Water_Crowfoot": "Ranunculus_trichophyllus",
    "White_Water_Lily": "Nymphaea_odorata"
}
df2008.columns = [scientific_names.get(key) for key in df2008.columns]

df2008.head()
# Out:
#   None       None None None None       None       None None None  \
# 0  428 2008-09-18    C   C1  1.0  42.977652 -75.887120    D    D
# 1  430 2008-09-18    C   C2  1.0  42.977520 -75.887213    M    S
# 2  431 2008-09-18    C   C3  2.0  42.977661 -75.887699    M    M
# 3  432 2008-09-18    C   C4  2.0  42.977674 -75.888337    D    S
# 4  433 2008-09-18    C   C5  2.0  42.977542 -75.889355    D    M
#
#   Callitriche_hermaphroditica  ... Nuphar_variegata Vallisneria_americana  \
# 0                           T  ...              NaN                   NaN
# 1                         NaN  ...              NaN                   NaN
# 2                         NaN  ...                M                   NaN
# 3                         NaN  ...                T                   NaN
# 4                         NaN  ...                S                   NaN
#
#   Potamogeton_gramineus Potamogeton_praelongus Megalodonta_beckii  \
# ...

# %%
df2008.columns.values[0] = 'excel_id'
df2008.columns.values[1] = 'date'
df2008.columns.values[2] = 'client_id'
df2008.columns.values[3] = 'Sample_Point_(SP)'
df2008.columns.values[4] = 'Depth_(ft)_August_2008_-_Allied_Biological'
df2008.columns.values[5] = 'Latitude'
df2008.columns.values[6] = 'Longitude'
df2008.columns.values[7] = 'Total_Submersed_Vegetation'
df2008.columns.values[8] = 'Total_Floating_Vegetation'

df2008.head()
# Out:
#    excel_id       date client_id Sample_Point_(SP)  \
# 0       428 2008-09-18         C                C1
# 1       430 2008-09-18         C                C2
# 2       431 2008-09-18         C                C3
# 3       432 2008-09-18         C                C4
# 4       433 2008-09-18         C                C5
#
#    Depth_(ft)_August_2008_-_Allied_Biological   Latitude  Longitude  \
# 0                                         1.0  42.977652 -75.887120
# 1                                         1.0  42.977520 -75.887213
# 2                                         2.0  42.977661 -75.887699
# 3                                         2.0  42.977674 -75.888337
# 4                                         2.0  42.977542 -75.889355
#
#   Total_Submersed_Vegetation Total_Floating_Vegetation  \
# 0                          D                         D
# 1                          M                         S
# 2                          M                         M
# ...

# %%
for index, row in df2008.iterrows():
  new_sample_point = row['Sample_Point_(SP)'].replace('C', '')
  df2008['Sample_Point_(SP)'][index] = new_sample_point
# Out:
# /tmp/ipykernel_525345/1661528176.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2008['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/1661528176.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2008['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/1661528176.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df2022 = pd.read_excel("input/rakeToss2022-AB.xlsx", sheet_name="TableB_AbundanceSpecies", skiprows=[0])
df2022.head()

for col in df2022.columns:
    df2022.rename(columns={col:col.strip().replace(" ","_")},inplace=True)

df2022.head()
# Out:
#    Sample_Point_(SP) Rake_Abundance Ceratophyllum_demersum Chara_vulgaris  \
# 0                  1              S                      S            NaN
# 1                  2              S                      S            NaN
# 2                  3              M                      M            NaN
# 3                  4              D                      D              T
# 4                  5              D                      M            NaN
#
#   Elodea_sp. Fontinalis_sp. Heteranthera_dubia Lemna_minor Lemna_trisculca  \
# 0          T            NaN                NaN           T               T
# 1          T            NaN                NaN           T               T
# 2          T            NaN                NaN         NaN             NaN
# 3          T            NaN                  T           T             NaN
# 4          T            NaN                  T           T             NaN
#
# ...

# %%
df2023 = pd.read_excel("input/rakeToss2023-AB.xlsx", sheet_name="TableB_AbundanceSpecies", skiprows=[0])

for col in df2023.columns:
    df2023.rename(columns={col:col.strip().replace(" ","_")},inplace=True)

df2023.head()
# Out:
#    Sample_Point_(SP) Rake_Abundance Ceratophyllum_demersum Chara_vulgaris  \
# 0                  1              D                      M            NaN
# 1                  2              D                      M            NaN
# 2                  3              D                      M            NaN
# 3                  4              D                      D            NaN
# 4                  5              D                      S              D
#
#   Elodea_sp. Fontinalis_sp. Heteranthera_dubia Hydrocharis_morsus-ranae  \
# 0          D            NaN                NaN                        S
# 1          D            NaN                NaN                        S
# 2          D            NaN                NaN                      NaN
# 3          M            NaN                NaN                      NaN
# 4          T            NaN                NaN                      NaN
#
#   Juncus_sp. Lemna_minor  ... Potamogeton_pusillus Potamogeton_richardsonii  \
# ...

# %%
years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
all_dfs = {}

for year in years:
    df = pd.read_excel("input/rakeToss2009-21-B.xlsx", sheet_name=f"{year}")
    
    for col in df.columns:
        df.rename(columns={col:col.strip().replace(" ","_")},inplace=True)

    all_dfs[year] = df

all_dfs[2020].head()
# Out:
# /home/kyle/caz_lake/rake-toss-data-cleaning/ve-dataprep/lib/python3.10/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# /home/kyle/caz_lake/rake-toss-data-cleaning/ve-dataprep/lib/python3.10/site-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#   Sample_Point_(SP)   Latitude  Longitude Rake_Abundance Rake_Abundance_#  \
# 0                C1   42.97768   75.88696              M             62.5
# 1                C2   42.97752  75.887213              M             62.5
# 2                C3  42.977661  75.887699              M             62.5
# 3                C4  42.977674  75.888337              M             62.5
# 4                C5  42.977542  75.889355              M             62.5
#
# ...

# %%
car_pond_2013 = pd.read_excel('input/rakeToss2009-21-B.xlsx', sheet_name='carpenterPond2013')
car_pond_2013
# Out:
#    Sample Point (SP)   Latitude     Longitude  Rake Abundance  \
# 0                CP1  42.927700  85740.000000               D
# 1                CP2  42.927358     75.865177               D
# 2                CP3  42.928090     75.858990               D
# 3                CP4  42.927410     75.858560               D
#
#    Rake Abundance #  Ceratophyllum demersum  Chara vulgaris  Elodea sp.  \
# 0               250                       S             NaN           S
# 1               250                       S               M           S
# 2               250                       S               M           S
# 3               250                       S             NaN           S
#
#    Fontinalis sp.  osterella dubia  ...   Potamogeton osteriformis  \
# 0             NaN              NaN  ...                        NaN
# 1               M                T  ...                        NaN
# 2               M              NaN  ...                        NaN
# ...

# %%
for col in car_pond_2013.columns:
        car_pond_2013.rename(columns={col:col.strip().replace(" ","_")},inplace=True)

# %%
for index, row in car_pond_2013.iterrows():
  new_sample_point = row['Sample_Point_(SP)'].replace('CP', '')
  car_pond_2013['Sample_Point_(SP)'][index] = new_sample_point
car_pond_2013
# Out:
# /tmp/ipykernel_525345/3527628732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_pond_2013['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/3527628732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_pond_2013['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/3527628732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
car_pond_2013.to_csv('output/table_B_car_pond_2013.csv')

# %% [markdown]
# Compare Yearly-Dataframes' column names and figure out how to match and organize them

# %%
column_comparison = {}
for year in years:
    column_comparison[year] = all_dfs[year].columns
  
column_comparison
# Out:
# {2009: Index(['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance',
#         'Abundance_#', 'Callitriche_hermaphroditica', 'Ceratophyllum_demersum',
#         'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia',
#         'Hypericum_ellipticum', 'Lemna_minor', 'Lemna_trisulca',
#         'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum',
#         'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis',
#         'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata',
#         'Polygonam_amphibium', 'Potamogeton_amplifolius', 'Potamogeton_crispus',
#         'Potamogeton_foliosus', 'Potamogeton_gramineus',
#         'Potamogeton_illinoensis', 'Potamogeton_praelongus',
#         'Potamogeton_pusillus', 'Potamogeton_richardsonii',
#         'Potamogeton_zosteriformis', 'Ranunculus_sp.', 'Spirodela_polyrhiza',
#         'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris',
# ...

# %%
for year in years:
    print(year, len(column_comparison[year]))
# Out:
# 2009 41
# 2010 37
# 2011 39
# 2012 39
# 2013 38
# 2014 41
# 2015 42
# 2016 45
# 2017 38
# 2018 39
# 2019 39
# 2020 40
# 2021 38

# %%
# for year in years:
#   num_cols = len(column_comparison[year])
#   if num_cols < 45:
#     for i in range(45-num_cols):
      # column_comparison[year].append(None)
# for year in years:
#     print(year, len(column_comparison[year]))

# DID ABOVE IN APPEND_COLS.PY

tableB_cols =  {'2009': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Abundance_#', 'Callitriche_hermaphroditica', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hypericum_ellipticum', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Polygonam_amphibium', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_sp.', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithaphora_sp.', None, None, None, None], '2010': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton__zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithaphora_sp.', None, None, None, None, None, None, None, None], '2011': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton__zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithaphora_sp.', 'Floating_Filamentous_Algae', None, None, None, None, None, None], '2012': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton__zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithaphora_sp.', 'Floating_Filamentous_Algae', None, None, None, None, None, None], '2013': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhia', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithaphora_sp.', 'Unnamed:_38', None, None, None, None, None, None], '2014': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Zannichellia_palustris', 'Pithophora_sp.', None, None, None, None], '2015': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Polygonum_amphibium', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Riccia_fluitans', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithophora_sp.', None, None, None], '2016': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Riccia_fluitans', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Zannichellia_palustris', 'Pithophora_sp.', 'Unnamed:_42', 'Unnamed:_43', 'Unnamed:_44'], '2017': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Polygonum_amphibium', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithophora_sp.', None, None, None, None, None, None, None], '2018': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Polygonum_amphibium', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithophora_sp.', None, None, None, None, None, None], '2019': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithophora_sp.', None, None, None, None, None, None], '2020': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Riccia_fluitans', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Utricularia_vulgaris', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithophora_sp.', None, None, None, None, None], '2021': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum', 'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Hydrocharis_morsus-ranae', 'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius', 'Potamogeton_crispus', 'Potamogeton_foliosus', 'Potamogeton_gramineus', 'Potamogeton_illinoensis', 'Potamogeton_praelongus', 'Potamogeton_pusillus', 'Potamogeton_richardsonii', 'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus', 'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Utricularia_sp.', 'Vallisneria_americana', 'Wolffia_columbiana', 'Pithophora_sp.', None, None, None, None, None, None, None]}

# %%
col_names = df.from_dict(tableB_cols)
col_names.to_csv("output/table_B_cols.csv")

# %%
# for copy/paste into Excel
for col in df2008.columns:
  print(col)
# Out:
# excel_id
# date
# client_id
# Sample_Point_(SP)
# Depth_(ft)_August_2008_-_Allied_Biological
# Latitude
# Longitude
# Total_Submersed_Vegetation
# Total_Floating_Vegetation
# Callitriche_hermaphroditica
# Potamogeton_amplifolius
# Benthic_Filamentous_Algae
# Potamogeton_richardsonii
# Utricularia_vulgaris
# Elodea_sp.
# Ceratophyllum_demersum
# Potamogeton_crispus
# Myriophyllum_spicatum
# Potamogeton_zosteriformis
# Floating_Filamentous_Algae
# Lemna_trisulca
# Spirodela_polyrhiza
# Potamogeton_illinoensis
# Potamogeton_foliosus
# Chara_vulgaris
# Potamogeton_pectinatus
# Najas_flexilis
# Lemna_minor
# Nuphar_variegata
# Vallisneria_americana
# Potamogeton_gramineus
# Potamogeton_praelongus
# Megalodonta_beckii
# Wolffia_columbiana
# Fontinalis_sp.
# Heteranthera_dubia
# Ranunculus_trichophyllus
# Nymphaea_odorata

# %%
# for copy/paste into Excel
for col in df2022.columns:
  print(col)
# Out:
# Sample_Point_(SP)
# Rake_Abundance
# Ceratophyllum_demersum
# Chara_vulgaris
# Elodea_sp.
# Fontinalis_sp.
# Heteranthera_dubia
# Lemna_minor
# Lemna_trisculca
# Megalodonta_beckii
# Myriophyllum_sibiricum
# Myriophyllum_spicatum
# Najas_flexilis
# Najas_guadalupensis
# Nitella_flexilis
# Nitellopsis_obtusa
# Nuphar_variegata
# Nymphaea_odorata
# Potamogeton_amplifolius
# Potamogeton_crispus_-_turions
# Potamogeton_crispus
# Potamogeton_foliosus
# Potamogeton_gramineus
# Potamogeton_illinoensis
# Potamogeton_praelongus
# Potamogeton_pusillus
# Potamogeton_richardsonii
# Potamogeton_zosteriformis
# Ranunculus_trichophyllus
# Stuckenia_pectinata
# Stuckenia_vaginata
# Utricularia_vulgaris
# Vallisneria_americana
# Wolffia_columbiana
# Pithophora_sp.

# %%
df2023 = df2023.rename(columns={'Potamogeton_crispus_turion': 'Potamogeton_crispus_turions'})

# %%
for col in df2023.columns:
  print(col)
# Out:
# Sample_Point_(SP)
# Rake_Abundance
# Ceratophyllum_demersum
# Chara_vulgaris
# Elodea_sp.
# Fontinalis_sp.
# Heteranthera_dubia
# Hydrocharis_morsus-ranae
# Juncus_sp.
# Lemna_minor
# Lemna_trisculca
# Ludwigia_sp.
# Megalodonta_beckii
# Myriophyllum_sibiricum
# Myriophyllum_spicatum
# Najas_flexilis
# Najas_guadalupensis
# Nitella_flexilis
# Nitellopsis_obtusa
# Nuphar_variegata
# Nymphaea_odorata
# Potamogeton_amplifolius
# Potamogeton_crispus
# Potamogeton_crispus_turions
# Potamogeton_foliosus
# Potamogeton_gramineus
# Potamogeton_illinoensis
# Potamogeton_praelongus
# Potamogeton_pusillus
# Potamogeton_richardsonii
# Potamogeton_zosteriformis
# Ranunculus_trichophyllus
# Spirodela_polyrhiza
# Stuckenia_pectinata
# Utricularia_vulgaris
# Vallisneria_americana
# Wolffia_columbiana
# Pithophora_sp.

# %%
df2022 = df2022.rename(columns={'Lemna_trisculca': 'Lemna_trisulca'})
df2022 = df2022.rename(columns={'Potamogeton_crispus_-_turions': 'Potamogeton_crispus_turions'})

df2022.columns
# Out:
# Index(['Sample_Point_(SP)', 'Rake_Abundance', 'Ceratophyllum_demersum',
#        'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia',
#        'Lemna_minor', 'Lemna_trisulca', 'Megalodonta_beckii',
#        'Myriophyllum_sibiricum', 'Myriophyllum_spicatum', 'Najas_flexilis',
#        'Najas_guadalupensis', 'Nitella_flexilis', 'Nitellopsis_obtusa',
#        'Nuphar_variegata', 'Nymphaea_odorata', 'Potamogeton_amplifolius',
#        'Potamogeton_crispus_turions', 'Potamogeton_crispus',
#        'Potamogeton_foliosus', 'Potamogeton_gramineus',
#        'Potamogeton_illinoensis', 'Potamogeton_praelongus',
#        'Potamogeton_pusillus', 'Potamogeton_richardsonii',
#        'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus',
#        'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris',
#        'Vallisneria_americana', 'Wolffia_columbiana', 'Pithophora_sp.'],
#       dtype='object')

# %%
all_dfs[2009].columns
# Out:
# Index(['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance',
#        'Abundance_#', 'Callitriche_hermaphroditica', 'Ceratophyllum_demersum',
#        'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia',
#        'Hypericum_ellipticum', 'Lemna_minor', 'Lemna_trisulca',
#        'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum',
#        'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis',
#        'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata',
#        'Polygonam_amphibium', 'Potamogeton_amplifolius', 'Potamogeton_crispus',
#        'Potamogeton_foliosus', 'Potamogeton_gramineus',
#        'Potamogeton_illinoensis', 'Potamogeton_praelongus',
#        'Potamogeton_pusillus', 'Potamogeton_richardsonii',
#        'Potamogeton_zosteriformis', 'Ranunculus_sp.', 'Spirodela_polyrhiza',
#        'Stuckenia_pectinata', 'Stuckenia_vaginata', 'Utricularia_vulgaris',
# ...

# %%
all_dfs[2009] = all_dfs[2009].rename(columns={'Ranunculus_sp.': 'Ranunculus_trichophyllus'})
all_dfs[2009].columns
# Out:
# Index(['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance',
#        'Abundance_#', 'Callitriche_hermaphroditica', 'Ceratophyllum_demersum',
#        'Chara_vulgaris', 'Elodea_sp.', 'Fontinalis_sp.', 'Heteranthera_dubia',
#        'Hypericum_ellipticum', 'Lemna_minor', 'Lemna_trisulca',
#        'Megalodonta_beckii', 'Myriophyllum_sibiricum', 'Myriophyllum_spicatum',
#        'Najas_flexilis', 'Najas_guadalupensis', 'Nitella_flexilis',
#        'Nitellopsis_obtusa', 'Nuphar_variegata', 'Nymphaea_odorata',
#        'Polygonam_amphibium', 'Potamogeton_amplifolius', 'Potamogeton_crispus',
#        'Potamogeton_foliosus', 'Potamogeton_gramineus',
#        'Potamogeton_illinoensis', 'Potamogeton_praelongus',
#        'Potamogeton_pusillus', 'Potamogeton_richardsonii',
#        'Potamogeton_zosteriformis', 'Ranunculus_trichophyllus',
#        'Spirodela_polyrhiza', 'Stuckenia_pectinata', 'Stuckenia_vaginata',
# ...

# %% [markdown]
# Grab milfoil column from each year and make a Dataframe of it *(while waiting for feedback on latin name matching)*

# %%
years = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# 17-21 also need title line repeats
milfoil_dfs = {}

for year in years:
  current_df = all_dfs[year]
  current_df.dropna(axis = 0, how = 'all', inplace = True)
  
  if year > 2016:
    # remove rows with column names repeated (for scrolling in Excel)
    current_df.drop(current_df[current_df['Latitude'] == ' Latitude'].index, inplace = True)
  
  for index, row in current_df.iterrows():
    # print(year, row['Sample_Point_(SP)'], type(row['Sample_Point_(SP)']))
    new_sample_point = row['Sample_Point_(SP)'].replace('C', '')
    current_df['Sample_Point_(SP)'][index] = new_sample_point

  milfoil_dfs[year] = current_df.filter(items=['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Myriophyllum_spicatum'])
  
  current_df.to_csv(f'output/table_B_{year}.csv')
  milfoil_dfs[year].to_csv(f'output/milfoil/table_B_{year}.csv')
# Out:
# /tmp/ipykernel_525345/1197665334.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/1197665334.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_df['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/1197665334.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
for index, row in df2008.iterrows():
  new_sample_point = row['Sample_Point_(SP)'].replace('C', '')
  df2008['Sample_Point_(SP)'][index] = new_sample_point
df2008
# Out:
# /tmp/ipykernel_525345/3086600291.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2008['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/3086600291.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2008['Sample_Point_(SP)'][index] = new_sample_point
# /tmp/ipykernel_525345/3086600291.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df2008.to_csv('output/table_B_2008.csv')

# %%
df2022.to_csv('output/table_B_2022.csv')

# %%
df2023.to_csv('output/table_B_2023.csv')

# %%
milfoil2022 = df2022.filter(items=['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Myriophyllum_spicatum'])
milfoil2022
# Out:
#      Sample_Point_(SP) Myriophyllum_spicatum
# 0                    1                   NaN
# 1                    2                   NaN
# 2                    3                     T
# 3                    4                     S
# 4                    5                     T
# ..                 ...                   ...
# 299                300                   NaN
# 300                301                   NaN
# 301                302                   NaN
# 302                303                   NaN
# 303                304                   NaN
#
# [304 rows x 2 columns]

# %%
milfoil2022.to_csv('output/milfoil/table_B_2022.csv')

# %%
milfoil2023 = df2023.filter(items=['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Myriophyllum_spicatum'])
milfoil2023
# Out:
#      Sample_Point_(SP) Myriophyllum_spicatum
# 0                    1                   NaN
# 1                    2                   NaN
# 2                    3                     M
# 3                    4                     D
# 4                    5                     T
# ..                 ...                   ...
# 297                300                     T
# 298                301                     T
# 299                302                     T
# 300                303                     S
# 301                304                     S
#
# [302 rows x 2 columns]

# %%
milfoil2023.to_csv('output/milfoil/table_B_2023.csv')

# %%
df_list = [df2008, all_dfs[2009], all_dfs[2010], all_dfs[2011], all_dfs[2012], all_dfs[2013], all_dfs[2014], all_dfs[2015], all_dfs[2016], all_dfs[2017], all_dfs[2018], all_dfs[2019], all_dfs[2020], all_dfs[2021], df2022, df2023]

year = 2008
all_titles = {}
for index, df in enumerate(df_list):
    title_list = list(df.columns)
    all_titles[f'df{year+index}'] = title_list
print(all_titles)
# del all_titles['df2009']
titles_df = pd.DataFrame.from_dict(all_titles, orient='index')

titles_df.to_csv('output/titlesTableB2010-23.csv')
# Out:
# {'df2008': ['excel_id', 'date', 'client_id', 'Sample_Point_(SP)', 'Depth_(ft)_August_2008_-_Allied_Biological', 'Latitude', 'Longitude', 'Total_Submersed_Vegetation', 'Total_Floating_Vegetation', 'Callitriche_hermaphroditica', 'Potamogeton_amplifolius', 'Benthic_Filamentous_Algae', 'Potamogeton_richardsonii', 'Utricularia_vulgaris', 'Elodea_sp.', 'Ceratophyllum_demersum', 'Potamogeton_crispus', 'Myriophyllum_spicatum', 'Potamogeton_zosteriformis ', 'Floating_Filamentous_Algae', 'Lemna_trisulca', 'Spirodela_polyrhiza', 'Potamogeton_illinoensis', 'Potamogeton_foliosus', 'Chara_vulgaris', 'Potamogeton_pectinatus', 'Najas_flexilis', 'Lemna_minor', 'Nuphar_variegata', 'Vallisneria_americana', 'Potamogeton_gramineus', 'Potamogeton_praelongus', 'Megalodonta_beckii', 'Wolffia_columbiana', 'Fontinalis_sp.', 'Heteranthera_dubia', 'Ranunculus_trichophyllus', 'Nymphaea_odorata'], 'df2009': ['Sample_Point_(SP)', 'Latitude', 'Longitude', 'Rake_Abundance', 'Abundance_#', 'Callitriche_hermaphroditic
# ...
